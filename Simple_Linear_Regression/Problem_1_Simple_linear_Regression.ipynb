# %% [markdown]
# Problem 2) Salary_hike -> Build a prediction model for Salary_hike

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
from sklearn.metrics import mean_squared_error
import random
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv("D:\ExcelR_Assignments\Simple_Linear_Regression(Completed)\Datasets\Salary_Data.csv")

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
# Checking for presence of outliers

# %%
plt.subplot(1,2,1)
sns.boxplot(df['YearsExperience'])
plt.title('YearsExperience')
plt.subplot(1,2,2)
sns.boxplot(df['Salary'])
plt.title('Salary')
plt.tight_layout()

# %%
# Both the columns are free from outliers

# %%
# Checking for skewness

# %%
plt.subplot(1,2,1)
sns.distplot(df['YearsExperience'])
plt.subplot(1,2,2)
sns.distplot(df['Salary'])
plt.tight_layout()

# %%
plt.subplot(1,2,1)
sns.distplot(df['YearsExperience'])
plt.title('YearsExperience')
plt.subplot(1,2,2)
sns.distplot(df['Salary'])
plt.title('Salary')
plt.tight_layout()

# %%
df.skew()
# Out:
# YearsExperience    0.37956
# Salary             0.35412
# dtype: float64

# %%
# There is moderate skewness present in both of the columns

# %%
# checking for correlation betweeen columns

# %%
sns.scatterplot(x=df['YearsExperience'], y=df['Salary'])
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
sns.regplot(x=df['YearsExperience'],y=df['Salary'])
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
df.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
# There is high positive skewness present between both the columns

# %%
# Checking for outliers present

# %%
plt.subplot(1,2,1)
sns.boxplot(df['YearsExperience'])
plt.title('YearsExperience')
plt.subplot(1,2,2)
sns.boxplot(df['Salary'])
plt.title('Salary')
plt.tight_layout()

# %%
# No outliers are present in both the columns

# %%
# Model Building

# %%
model1 = smf.ols('Salary~YearsExperience', data=df).fit()
model1

# %%
# Model1 is ready
# Checking for model1 parameters and pvalues

# %%
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Salary   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     622.5
# Date:                Tue, 13 Feb 2024   Prob (F-statistic):           1.14e-20
# Time:                        18:57:54   Log-Likelihood:                -301.44
# No. Observations:                  30   AIC:                             606.9
# Df Residuals:                      28   BIC:                             609.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept        2.579e+04   2273.053     11.347      0.000    2.11e+04    3.04e+04
# YearsExperience  9449.9623    378.755     24.950      0.000    8674.119    1.02e+04
# ==============================================================================
# Omnibus:                        2.140   Durbin-Watson:                   1.648
# Prob(Omnibus):                  0.343   Jarque-Bera (JB):                1.569
# Skew:                           0.363   Prob(JB):                        0.456
# Kurtosis:                       2.147   Cond. No.                         13.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model1.params
# Out:
# Intercept          25792.200199
# YearsExperience     9449.962321
# dtype: float64

# %%
model1.pvalues
# Out:
# Intercept          5.511950e-12
# YearsExperience    1.143068e-20
# dtype: float64

# %%
# here pvalue < alpha(0.05), so we are rejecting Null hypothesis. i.e. m=0

# %%
# calculating r2 values for checking accuracy of model

# %%
model1.rsquared
# Out:
# 0.9569566641435086

# %%
# Here our Model1 is having 95% accuracy
# Predicting for new salaries.

# %%
test = pd.DataFrame({
    'YearsExperience' : [round(random.uniform(1, 15), 1) for _ in range(30)]
})
test
# Out:
#     YearsExperience
# 0               6.8
# 1              10.1
# 2              10.3
# 3               2.1
# 4               3.2
# 5               3.6
# 6              14.1
# 7               8.0
# 8              13.7
# 9               9.8
# 10             10.5
# 11              8.4
# 12              1.2
# 13              5.1
# 14              9.6
# 15              6.1
# 16              7.2
# 17             12.8
# 18              8.4
# 19              7.0
# 20             12.7
# 21              5.7
# 22              2.0
# 23              8.0
# 24              2.5
# 25             13.8
# 26              8.4
# 27             11.1
# 28             11.4
# 29              7.4

# %%
df['m1_predicted_salary'] = model1.predict(test)
df
# Out:
#     YearsExperience    Salary  m1_predicted_salary
# 0               1.1   39343.0         90051.943985
# 1               1.3   46205.0        121236.819645
# 2               1.5   37731.0        123126.812110
# 3               2.0   43525.0         45637.121074
# 4               2.2   39891.0         56032.079627
# 5               2.9   56642.0         59812.064556
# 6               3.0   60150.0        159036.668931
# 7               3.2   54445.0        101391.898770
# 8               3.2   64445.0        155256.684003
# 9               3.7   57189.0        118401.830949
# 10              3.9   63218.0        125016.804574
# 11              4.0   55794.0        105171.883699
# 12              4.0   56957.0         37132.154984
# 13              4.1   57081.0         73987.008038
# 14              4.5   61111.0        116511.838485
# 15              4.9   67938.0         83436.970360
# 16              5.1   66029.0         93831.928913
# 17              5.3   83088.0        146751.717913
# 18              5.9   81363.0        105171.883699
# 19              6.0   93940.0         91941.936449
# 20              6.8   91738.0        145806.721681
# 21              7.1   98273.0         79656.985431
# 22              7.9  101302.0         44692.124842
# 23              8.2  113812.0        101391.898770
# 24              8.7  109431.0         49417.106002
# 25              9.0  105582.0        156201.680235
# 26              9.5  116969.0        105171.883699
# 27              9.6  112635.0        130686.781967
# 28             10.3  122391.0        133521.770663
# 29             10.5  121872.0         95721.921377

# %%
# Checking MSE and RMSE values for model1

# %%
predicted_values = df['m1_predicted_salary']
MSE_model1 = mean_squared_error(df['Salary'], predicted_values)
RMSE_model1 = np.sqrt(MSE_model1)
print('MSE Of Model 1 = ', MSE_model1, '\nRMSE of Model 1 = ', RMSE_model1)
# Out:
# MSE Of Model 1 =  2315107315.7658086
# RMSE of Model 1 =  48115.56209549888

# %%
# Data Transformation
#1. log method

# %%
df['log_yearsexperience'] = np.log(df['YearsExperience'])
df['log_salary'] = np.log(df['Salary'])
df
# Out:
#     YearsExperience    Salary  m1_predicted_salary  log_yearsexperience  \
# 0               1.1   39343.0         90051.943985             0.095310
# 1               1.3   46205.0        121236.819645             0.262364
# 2               1.5   37731.0        123126.812110             0.405465
# 3               2.0   43525.0         45637.121074             0.693147
# 4               2.2   39891.0         56032.079627             0.788457
# 5               2.9   56642.0         59812.064556             1.064711
# 6               3.0   60150.0        159036.668931             1.098612
# 7               3.2   54445.0        101391.898770             1.163151
# 8               3.2   64445.0        155256.684003             1.163151
# 9               3.7   57189.0        118401.830949             1.308333
# 10              3.9   63218.0        125016.804574             1.360977
# 11              4.0   55794.0        105171.883699             1.386294
# 12              4.0   56957.0         37132.154984             1.386294
# 13              4.1   57081.0         73987.008038             1.410987
# 14              4.5   61111.0        116511.838485             1.504077
# 15              4.9   67938.0         83436.970360             1.589235
# 16              5.1   66029.0         93831.928913             1.629241
# 17              5.3   83088.0        146751.717913             1.667707
# 18              5.9   81363.0        105171.883699             1.774952
# 19              6.0   93940.0         91941.936449             1.791759
# 20              6.8   91738.0        145806.721681             1.916923
# 21              7.1   98273.0         79656.985431             1.960095
# 22              7.9  101302.0         44692.124842             2.066863
# 23              8.2  113812.0        101391.898770             2.104134
# 24              8.7  109431.0         49417.106002             2.163323
# 25              9.0  105582.0        156201.680235             2.197225
# 26              9.5  116969.0        105171.883699             2.251292
# 27              9.6  112635.0        130686.781967             2.261763
# 28             10.3  122391.0        133521.770663             2.332144
# 29             10.5  121872.0         95721.921377             2.351375
#
#     log_salary
# 0    10.580073
# 1    10.740843
# 2    10.538237
# 3    10.681091
# 4    10.593906
# 5    10.944506
# 6    11.004597
# 7    10.904946
# 8    11.073567
# 9    10.954117
# 10   11.054344
# 11   10.929422
# 12   10.950052
# 13   10.952227
# 14   11.020447
# 15   11.126351
# 16   11.097849
# 17   11.327656
# 18   11.306676
# 19   11.450412
# 20   11.426692
# 21   11.495505
# 22   11.525861
# 23   11.642303
# 24   11.603049
# 25   11.567243
# 26   11.669664
# 27   11.631908
# 28   11.714976
# 29   11.710727

# %%
# Checking for skewness

# %%
df['log_yearsexperience'].skew(), df['log_salary'].skew()
# Out:
# (-0.6005648582626513, -0.044126086756988495)

# %%
# Here both of the columns are having moderate negative skewness but having less as compared to model1
# lets build model2 using log method

# %%
model2 = smf.ols('log_salary~log_yearsexperience', data=df).fit()
model2

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             log_salary   R-squared:                       0.905
# Model:                            OLS   Adj. R-squared:                  0.902
# Method:                 Least Squares   F-statistic:                     267.4
# Date:                Tue, 13 Feb 2024   Prob (F-statistic):           7.40e-16
# Time:                        18:58:41   Log-Likelihood:                 23.209
# No. Observations:                  30   AIC:                            -42.42
# Df Residuals:                      28   BIC:                            -39.61
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              10.3280      0.056    184.868      0.000      10.214      10.442
# log_yearsexperience     0.5621      0.034     16.353      0.000       0.492       0.632
# ==============================================================================
# Omnibus:                        0.102   Durbin-Watson:                   0.988
# Prob(Omnibus):                  0.950   Jarque-Bera (JB):                0.297
# Skew:                           0.093   Prob(JB):                        0.862
# Kurtosis:                       2.549   Cond. No.                         5.76
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Checking for model2 parameters and pvalues

# %%
model2.params
# Out:
# Intercept              10.328043
# log_yearsexperience     0.562089
# dtype: float64

# %%
model2.pvalues
# Out:
# Intercept              9.073132e-45
# log_yearsexperience    7.395278e-16
# dtype: float64

# %%
# here pvalue < alpha(0.05), so we are rejecting Null hypothesis. i.e. m=0

# %%
# Checking for r2 value

# %%
model2.rsquared
# Out:
# 0.905215072581715

# %%
# Here our model2 accuracy is 90%
# predicting new salary using model2

# %%
test2 = pd.DataFrame({
    'log_yearsexperience' : [round(random.uniform(1, 15), 1) for _ in range(30)]
})
test2
# Out:
#     log_yearsexperience
# 0                   1.9
# 1                   9.1
# 2                  10.5
# 3                   5.8
# 4                   1.7
# 5                  12.2
# 6                   7.5
# 7                   3.8
# 8                   3.8
# 9                  10.6
# 10                 11.6
# 11                 11.7
# 12                  7.7
# 13                 10.7
# 14                 13.6
# 15                  4.0
# 16                 14.8
# 17                 14.5
# 18                 10.8
# 19                  8.1
# 20                  4.8
# 21                 10.4
# 22                 14.5
# 23                  7.4
# 24                 14.7
# 25                 10.2
# 26                  1.2
# 27                  5.1
# 28                 10.3
# 29                  8.8

# %%
df['m2_predicted_salary'] = model2.predict(test2)
df
# Out:
#     YearsExperience    Salary  m1_predicted_salary  log_yearsexperience  \
# 0               1.1   39343.0         90051.943985             0.095310
# 1               1.3   46205.0        121236.819645             0.262364
# 2               1.5   37731.0        123126.812110             0.405465
# 3               2.0   43525.0         45637.121074             0.693147
# 4               2.2   39891.0         56032.079627             0.788457
# 5               2.9   56642.0         59812.064556             1.064711
# 6               3.0   60150.0        159036.668931             1.098612
# 7               3.2   54445.0        101391.898770             1.163151
# 8               3.2   64445.0        155256.684003             1.163151
# 9               3.7   57189.0        118401.830949             1.308333
# 10              3.9   63218.0        125016.804574             1.360977
# 11              4.0   55794.0        105171.883699             1.386294
# 12              4.0   56957.0         37132.154984             1.386294
# 13              4.1   57081.0         73987.008038             1.410987
# 14              4.5   61111.0        116511.838485             1.504077
# 15              4.9   67938.0         83436.970360             1.589235
# 16              5.1   66029.0         93831.928913             1.629241
# 17              5.3   83088.0        146751.717913             1.667707
# 18              5.9   81363.0        105171.883699             1.774952
# 19              6.0   93940.0         91941.936449             1.791759
# 20              6.8   91738.0        145806.721681             1.916923
# 21              7.1   98273.0         79656.985431             1.960095
# 22              7.9  101302.0         44692.124842             2.066863
# 23              8.2  113812.0        101391.898770             2.104134
# 24              8.7  109431.0         49417.106002             2.163323
# 25              9.0  105582.0        156201.680235             2.197225
# 26              9.5  116969.0        105171.883699             2.251292
# 27              9.6  112635.0        130686.781967             2.261763
# 28             10.3  122391.0        133521.770663             2.332144
# 29             10.5  121872.0         95721.921377             2.351375
#
#     log_salary  m2_predicted_salary
# 0    10.580073            11.396012
# 1    10.740843            15.443052
# 2    10.538237            16.229976
# 3    10.681091            13.588158
# 4    10.593906            11.283594
# 5    10.944506            17.185527
# 6    11.004597            14.543709
# 7    10.904946            12.463981
# 8    11.073567            12.463981
# 9    10.954117            16.286185
# 10   11.054344            16.848274
# 11   10.929422            16.904483
# 12   10.950052            14.656127
# 13   10.952227            16.342394
# 14   11.020447            17.972451
# 15   11.126351            12.576399
# 16   11.097849            18.646958
# 17   11.327656            18.478331
# 18   11.306676            16.398603
# 19   11.450412            14.880963
# 20   11.426692            13.026070
# 21   11.495505            16.173767
# 22   11.525861            18.478331
# 23   11.642303            14.487501
# 24   11.603049            18.590749
# 25   11.567243            16.061349
# 26   11.669664            11.002550
# 27   11.631908            13.194696
# 28   11.714976            16.117558
# 29   11.710727            15.274425

# %%
# Calculating MSE and RMSE of model2

# %%
predicted_values = df['m2_predicted_salary']
MSE_model2 = mean_squared_error(df['Salary'], predicted_values)
RMSE_model2 = np.sqrt(MSE_model2)
print('MSE Of Model 2 = ', MSE_model2, '\nRMSE of Model 2 = ', RMSE_model2)
# Out:
# MSE Of Model 2 =  6500625688.131293
# RMSE of Model 2 =  80626.4577426746

# %%
# Data Transformation
#2. sqrt method

# %%
df['sqrt_yearsexperience'] = np.sqrt(df['YearsExperience'])
df['sqrt_salary'] = np.sqrt(df['Salary'])
df
# Out:
#     YearsExperience    Salary  m1_predicted_salary  log_yearsexperience  \
# 0               1.1   39343.0         90051.943985             0.095310
# 1               1.3   46205.0        121236.819645             0.262364
# 2               1.5   37731.0        123126.812110             0.405465
# 3               2.0   43525.0         45637.121074             0.693147
# 4               2.2   39891.0         56032.079627             0.788457
# 5               2.9   56642.0         59812.064556             1.064711
# 6               3.0   60150.0        159036.668931             1.098612
# 7               3.2   54445.0        101391.898770             1.163151
# 8               3.2   64445.0        155256.684003             1.163151
# 9               3.7   57189.0        118401.830949             1.308333
# 10              3.9   63218.0        125016.804574             1.360977
# 11              4.0   55794.0        105171.883699             1.386294
# 12              4.0   56957.0         37132.154984             1.386294
# 13              4.1   57081.0         73987.008038             1.410987
# 14              4.5   61111.0        116511.838485             1.504077
# 15              4.9   67938.0         83436.970360             1.589235
# 16              5.1   66029.0         93831.928913             1.629241
# 17              5.3   83088.0        146751.717913             1.667707
# 18              5.9   81363.0        105171.883699             1.774952
# 19              6.0   93940.0         91941.936449             1.791759
# 20              6.8   91738.0        145806.721681             1.916923
# 21              7.1   98273.0         79656.985431             1.960095
# 22              7.9  101302.0         44692.124842             2.066863
# 23              8.2  113812.0        101391.898770             2.104134
# 24              8.7  109431.0         49417.106002             2.163323
# 25              9.0  105582.0        156201.680235             2.197225
# 26              9.5  116969.0        105171.883699             2.251292
# 27              9.6  112635.0        130686.781967             2.261763
# 28             10.3  122391.0        133521.770663             2.332144
# 29             10.5  121872.0         95721.921377             2.351375
#
#     log_salary  m2_predicted_salary  sqrt_yearsexperience  sqrt_salary
# 0    10.580073            11.396012              1.048809   198.350700
# 1    10.740843            15.443052              1.140175   214.953483
# 2    10.538237            16.229976              1.224745   194.244691
# 3    10.681091            13.588158              1.414214   208.626460
# 4    10.593906            11.283594              1.483240   199.727314
# 5    10.944506            17.185527              1.702939   237.995798
# 6    11.004597            14.543709              1.732051   245.254969
# 7    10.904946            12.463981              1.788854   233.334524
# 8    11.073567            12.463981              1.788854   253.860198
# 9    10.954117            16.286185              1.923538   239.142217
# 10   11.054344            16.848274              1.974842   251.431899
# 11   10.929422            16.904483              2.000000   236.207536
# 12   10.950052            14.656127              2.000000   238.656657
# 13   10.952227            16.342394              2.024846   238.916303
# 14   11.020447            17.972451              2.121320   247.206392
# 15   11.126351            12.576399              2.213594   260.649190
# 16   11.097849            18.646958              2.258318   256.961087
# 17   11.327656            18.478331              2.302173   288.249892
# 18   11.306676            16.398603              2.428992   285.242003
# 19   11.450412            14.880963              2.449490   306.496330
# 20   11.426692            13.026070              2.607681   302.882816
# 21   11.495505            16.173767              2.664583   313.485247
# 22   11.525861            18.478331              2.810694   318.279751
# 23   11.642303            14.487501              2.863564   337.360341
# 24   11.603049            18.590749              2.949576   330.803567
# 25   11.567243            16.061349              3.000000   324.933839
# 26   11.669664            11.002550              3.082207   342.007310
# 27   11.631908            13.194696              3.098387   335.611382
# 28   11.714976            16.117558              3.209361   349.844251
# 29   11.710727            15.274425              3.240370   349.101704

# %%
# Checking for skewness

# %%
df['sqrt_yearsexperience'].skew() , df['sqrt_salary'].skew()
# Out:
# (-0.04919608394250605, 0.16904336802767353)

# %%
# Now we can see sqrt method has reduced skewness of data more than log method
# so we are using sqrt method for model building

# %%
sns.regplot(x=df['sqrt_yearsexperience'],y=df['sqrt_salary'])
# Out:
# <Axes: xlabel='sqrt_yearsexperience', ylabel='sqrt_salary'>

# %%
# There is high positive relation between both columns

# %%
# model building

# %%
model3 = smf.ols('sqrt_salary~sqrt_yearsexperience', data=df).fit()
model3

# %%
# here model is ready

# %%
model3.params
# Out:
# Intercept               103.568031
# sqrt_yearsexperience     75.626932
# dtype: float64

# %%
# checking pvalue

# %%
model3.pvalues
# Out:
# Intercept               4.141645e-13
# sqrt_yearsexperience    7.584326e-19
# dtype: float64

# %%
# here pvalue < alpha(0.05), so we are rejecting Null hypothesis. i.e. m=0

# %%
# chekcing for r2 value

# %%
model3.rsquared
# Out:
# 0.9419490138976825

# %%
# Our model has 94% accuracy

# %%
# Predicting Salary hike based on years of experience

# %%
test = pd.DataFrame({
    'sqrt_yearsexperience' : [round(random.uniform(1, 15), 1) for _ in range(30)]
})
test
# Out:
#     sqrt_yearsexperience
# 0                    4.1
# 1                    5.5
# 2                    8.4
# 3                   13.0
# 4                   13.9
# 5                   12.8
# 6                    6.5
# 7                   12.5
# 8                   12.2
# 9                    4.1
# 10                  11.4
# 11                  10.8
# 12                   7.7
# 13                   4.8
# 14                  11.5
# 15                   5.1
# 16                   1.7
# 17                   6.3
# 18                   4.0
# 19                  12.9
# 20                   5.5
# 21                   7.3
# 22                  12.5
# 23                  11.6
# 24                  13.4
# 25                  14.9
# 26                  12.1
# 27                   1.7
# 28                  12.9
# 29                   5.8

# %%
df['m3_predicted_salary'] = model.predict(test)
df
# Out:
#     YearsExperience    Salary  m1_predicted_salary  log_yearsexperience  \
# 0               1.1   39343.0         90051.943985             0.095310
# 1               1.3   46205.0        121236.819645             0.262364
# 2               1.5   37731.0        123126.812110             0.405465
# 3               2.0   43525.0         45637.121074             0.693147
# 4               2.2   39891.0         56032.079627             0.788457
# 5               2.9   56642.0         59812.064556             1.064711
# 6               3.0   60150.0        159036.668931             1.098612
# 7               3.2   54445.0        101391.898770             1.163151
# 8               3.2   64445.0        155256.684003             1.163151
# 9               3.7   57189.0        118401.830949             1.308333
# 10              3.9   63218.0        125016.804574             1.360977
# 11              4.0   55794.0        105171.883699             1.386294
# 12              4.0   56957.0         37132.154984             1.386294
# 13              4.1   57081.0         73987.008038             1.410987
# 14              4.5   61111.0        116511.838485             1.504077
# 15              4.9   67938.0         83436.970360             1.589235
# 16              5.1   66029.0         93831.928913             1.629241
# 17              5.3   83088.0        146751.717913             1.667707
# 18              5.9   81363.0        105171.883699             1.774952
# 19              6.0   93940.0         91941.936449             1.791759
# 20              6.8   91738.0        145806.721681             1.916923
# 21              7.1   98273.0         79656.985431             1.960095
# 22              7.9  101302.0         44692.124842             2.066863
# 23              8.2  113812.0        101391.898770             2.104134
# 24              8.7  109431.0         49417.106002             2.163323
# 25              9.0  105582.0        156201.680235             2.197225
# 26              9.5  116969.0        105171.883699             2.251292
# 27              9.6  112635.0        130686.781967             2.261763
# 28             10.3  122391.0        133521.770663             2.332144
# 29             10.5  121872.0         95721.921377             2.351375
#
#     log_salary  m2_predicted_salary  sqrt_yearsexperience  sqrt_salary  \
# 0    10.580073            11.396012              1.048809   198.350700
# 1    10.740843            15.443052              1.140175   214.953483
# 2    10.538237            16.229976              1.224745   194.244691
# 3    10.681091            13.588158              1.414214   208.626460
# 4    10.593906            11.283594              1.483240   199.727314
# 5    10.944506            17.185527              1.702939   237.995798
# 6    11.004597            14.543709              1.732051   245.254969
# 7    10.904946            12.463981              1.788854   233.334524
# 8    11.073567            12.463981              1.788854   253.860198
# 9    10.954117            16.286185              1.923538   239.142217
# 10   11.054344            16.848274              1.974842   251.431899
# 11   10.929422            16.904483              2.000000   236.207536
# 12   10.950052            14.656127              2.000000   238.656657
# 13   10.952227            16.342394              2.024846   238.916303
# 14   11.020447            17.972451              2.121320   247.206392
# 15   11.126351            12.576399              2.213594   260.649190
# 16   11.097849            18.646958              2.258318   256.961087
# 17   11.327656            18.478331              2.302173   288.249892
# 18   11.306676            16.398603              2.428992   285.242003
# 19   11.450412            14.880963              2.449490   306.496330
# 20   11.426692            13.026070              2.607681   302.882816
# 21   11.495505            16.173767              2.664583   313.485247
# 22   11.525861            18.478331              2.810694   318.279751
# 23   11.642303            14.487501              2.863564   337.360341
# 24   11.603049            18.590749              2.949576   330.803567
# 25   11.567243            16.061349              3.000000   324.933839
# 26   11.669664            11.002550              3.082207   342.007310
# 27   11.631908            13.194696              3.098387   335.611382
# 28   11.714976            16.117558              3.209361   349.844251
# 29   11.710727            15.274425              3.240370   349.101704
#
#     m3_predicted_salary
# 0            413.638451
# 1            519.516156
# 2            738.834259
# 3           1086.718145
# 4           1154.782384
# 5           1071.592759
# 6            595.143088
# 7           1048.904679
# 8           1026.216600
# 9            413.638451
# 10           965.715054
# 11           920.338895
# 12           685.895406
# 13           466.577304
# 14           973.277747
# 15           489.265383
# 16           232.133815
# 17           580.017702
# 18           406.075758
# 19          1079.155452
# 20           519.516156
# 21           655.644634
# 22          1048.904679
# 23           980.840441
# 24          1116.968918
# 25          1230.409316
# 26          1018.653907
# 27           232.133815
# 28          1079.155452
# 29           542.204236

# %%
# We can see that as the Years of Experience increases Salary of employee also increases

# %%
# checking for MSE and RMSE values

# %%
predicted_values = df['m3_predicted_salary']
MSE_model3 = mean_squared_error(df['Salary'], predicted_values)
RMSE_model3 = np.sqrt(MSE_model2)
print('MSE Of Model 3 = ', MSE_model3, '\nRMSE of Model 3 = ', RMSE_model3)
# Out:
# MSE Of Model 3 =  6383698484.654802
# RMSE of Model 3 =  80626.4577426746

# %%
print('MSE Of Model 1 = ', MSE_model1, 'RMSE of Model 1 = ', RMSE_model1)
print('MSE Of Model 2 = ', MSE_model2, 'RMSE of Model 2 = ', RMSE_model2)
print('MSE Of Model 3 = ', MSE_model3, 'RMSE of Model 3 = ', RMSE_model3)
# Out:
# MSE Of Model 1 =  2315107315.7658086 RMSE of Model 1 =  48115.56209549888
# MSE Of Model 2 =  6500625688.131293 RMSE of Model 2 =  80626.4577426746
# MSE Of Model 3 =  6383698484.654802 RMSE of Model 3 =  80626.4577426746
